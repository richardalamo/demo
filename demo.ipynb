# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df.head(3)
# Out:
#    _evidently_index                                            queries  \
# 0                 0  How does the RFP differentiate between mandato...
# 1                 1  Under the "Service and Maintenance" section, w...
# 2                 2  In Appendix D (Pricing Structure), what criter...
#
#                                            responses  \
# 0  The RFP distinguishes between **mandatory** an...
# 1  To substantiate claimed uptime percentages und...
# 2  The RFP specifies that **volume discounts** in...
#
#                                              context
# 0  USask shall not be bound and the Proponents ag...
# 1  Adjustments decreasing pricing structure \nsho...
# 2  Additionally, they \nshould indicate whether a...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _evidently_index  5 non-null      int64
#  1   queries           5 non-null      object
#  2   responses         5 non-null      object
#  3   context           5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 292.0+ bytes

# %%
df['_evidently_index'] = df['_evidently_index'] + 1

# %%
df
# Out:
#    _evidently_index                                            queries  \
# 0                 1  How does the RFP differentiate between mandato...
# 1                 2  Under the "Service and Maintenance" section, w...
# 2                 3  In Appendix D (Pricing Structure), what criter...
# 3                 4  According to Section 3.23 (Copyright Licence/R...
# 4                 5  For the "Indigenous Participation" evaluation ...
#
#                                            responses  \
# 0  The RFP distinguishes between **mandatory** an...
# 1  To substantiate claimed uptime percentages und...
# 2  The RFP specifies that **volume discounts** in...
# 3  According to **Section 3.23 (Copyright Licence...
# 4  To demonstrate **Indigenous ownership** or **c...
#
#                                              context
# 0  USask shall not be bound and the Proponents ag...
# 1  Adjustments decreasing pricing structure \nsho...
# 2  Additionally, they \nshould indicate whether a...
# ...
